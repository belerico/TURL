# %% [markdown]
# ## Note
#
# This notebook is designed to run an analysis on the CEA (Entity Linking) dataset created by the TURL authors

# %%
from __future__ import annotations

import ast
import json
import os
import pickle
import unicodedata
import urllib.parse
import urllib.request
from multiprocessing import Pool
from typing import List

import numpy as np
import pandas as pd
import requests

# %%
dataset_path = "~/turl-data/t2d.table_entity_linking.json"
dataset_path = os.path.expanduser(dataset_path)

# %%
with open(dataset_path, "r") as f:
    tables = json.load(f)

# %%
len(tables)
# Out:
# 809

# %%
table_id, pgTitle, secTitle, caption, headers, entities, candidate_entities, labels, _ = tables[0]

# %%
entities
# Out:
# [[[3, 0], 'australia'],
#  [[3, 1], 'AUD'],
#  [[3, 2], 'Australian Dollars'],
#  [[24, 0], 'israel'],
#  [[24, 1], 'ILS'],
#  [[24, 2], 'Israeli New Shekels'],
#  [[52, 0], 'zambia'],
#  [[52, 1], 'ZMK'],
#  [[52, 2], 'Zambian Kwacha'],
#  [[6, 0], 'bermuda'],
#  [[6, 1], 'BMD'],
#  [[6, 2], 'Bermudan Dollars'],
#  [[36, 0], 'poland'],
#  [[36, 1], 'PLZ'],
#  [[36, 2], 'Polish Zloty'],
#  [[43, 0], 'south korea'],
#  [[43, 1], 'KRW'],
#  [[43, 2], 'South Korean Won'],
#  [[17, 0], 'fiji'],
#  [[17, 1], 'FJD'],
#  [[17, 2], 'Fiji Dollars'],
#  [[13, 0], 'czech republic'],
#  [[13, 1], 'CZK'],
#  [[13, 2], 'Czech Koruna'],
#  [[29, 0], 'lebanon'],
#  [[29, 1], 'LBP'],
#  [[29, 2], 'Lebanese Pounds'],
#  [[26, 0], 'japan'],
#  [[26, 1], 'JPY'],
#  [[26, 2], 'Japanese Yen'],
#  [[32, 0], 'new zealand'],
#  [[32, 1], 'NZD'],
#  [[32, 2], 'New Zealand Dollars'],
#  [[46, 0], 'switzerland'],
#  [[46, 1], 'CHF'],
#  [[46, 2], 'Swiss Francs'],
#  [[48, 0], 'thailand'],
#  [[48, 1], 'THB'],
#  [[48, 2], 'Thai Baht'],
#  [[22, 0], 'india'],
#  [[22, 1], 'INR'],
#  [[22, 2], 'Indian Rupees'],
#  [[27, 0], 'jordan'],
#  [[27, 1], 'JOD'],
#  [[27, 2], 'Jordanian Dinar'],
#  [[45, 0], 'sweden'],
#  [[45, 1], 'SEK'],
#  [[45, 2], 'Swedish Krona'],
#  [[23, 0], 'indonesia'],
#  [[23, 1], 'IDR'],
#  [[23, 2], 'Indonesian Rupiah'],
#  [[42, 0], 'south africa'],
#  [[42, 1], 'ZAR'],
#  [[42, 2], 'South African Rand'],
#  [[7, 0], 'brazil'],
#  [[7, 1], 'BRL'],
#  [[7, 2], 'Brazilian Real'],
#  [[25, 0], 'jamaica'],
#  [[25, 1], 'JMD'],
#  [[25, 2], 'Jamaican Dollars'],
#  [[9, 0], 'canada'],
#  [[9, 1], 'CAD'],
#  [[9, 2], 'Canadian Dollars'],
#  [[21, 0], 'iceland'],
#  [[21, 1], 'ISK'],
#  [[21, 2], 'Icelandic Krona'],
#  [[19, 0], 'hong kong'],
#  [[19, 1], 'HKD'],
#  [[19, 2], 'Hong Kong Dollars'],
#  [[2, 0], 'argentina'],
#  [[2, 1], 'ARP'],
#  [[2, 2], 'Argentinean Pesos'],
#  [[49, 0], 'turkey'],
#  [[49, 1], 'TRY'],
#  [[49, 2], 'Turkish Lira (New)'],
#  [[4, 0], 'bahamas'],
#  [[4, 1], 'BSD'],
#  [[4, 2], 'Bahamas Dollars']]

# %%
candidate_entities
# Out:
# [['Australia', 'island country in the Southern hemisphere', ['Country']],
#  ['Australia', "continent on the Earth's Southern Hemisphere", ['Continent']],
#  ['Australia', 'Wikimedia disambiguation page', []],
#  ['Australia', '2008 film by Baz Luhrmann', []],
#  ['8088 Australia', 'main-belt asteroid', []],
#  ['Australian rules football', 'sport', ['Sport']],
#  ['National Library of Australia',
#   'national reference library in Canberra, Australia',
#   ['Library']],
#  ['Australia', 'Racehorse', ['RaceHorse']],
#  ['Australia', '1989 film by Jean-Jacques Andrien', ['Film']],
#  ['Australia', 'Manic Street Preachers song', ['Song']],
#  ['Australian Capital Territory',
#   'federal territory of Australia, containing the capital city, Canberra',
#   ['AdministrativeRegion']],
#  ['Australia', 'board game', ['Game']],
#  ['Australian National University',
#   'national research university in Canberra, Australian Capital Territory, Australia',
#   []],
#  ['Australia', 'The Shins song', ['Song']],
#  ['Australia', 'fourth studio album released by Mango', ['Album']],
#  ['Australia', 'Howie Day album', ['Album']],
#  ['Australia', 'episode of Modern Family', ['TelevisionEpisode']],
#  ['Australia', 'song by music group Gyroscope', ['Song']],
#  ['Australia', 'painting by Roger Huyssen', []],
#  ['Australia', 'yacht that raced in the Americas Cup', []],
#  ['Australia', '2009 Romanian film', []],
#  ['Australia', '1997 album', []],
#  ['Australia', 'manuscript map [drawn by Erwin] Raisz', []],
#  ['Australia', None, []],
#  ['Australia', '1992 unreleased Indian film directed by Rajiv Anchal', []],
#  ['Australian Labor Party',
#   'political party in Australia',
#   ['PoliticalParty']],
#  ['Australia', 'albedo feature on the planet Mercury', []],
#  ['Australia', 'song by the British rock band The Kinks', ['Song']],
#  ['Australia', 'schooner', ['Ship']],
#  ['Australia', 'scientific article published on 01 January 1988', []],
#  ['Australia', None, []],
#  ['Australia', 'article', []],
#  ['Australia', None, []],
#  ['Australia', 'scientific article published in Nature', []],
#  ['Australia', None, []],
#  ['Australia', None, []],
#  ['Australia', 'scientific article published in November 1929', []],
#  ['Australia', None, []],
#  ['Australia', None, []],
#  ['Australia', None, []],
#  ['Australia', None, []],
#  ['Australia', 'scientific article published in August 1920', []],
#  ['The Australia', 'pub in Porthmadog, Wales', []],
#  ['Australia', None, []],
#  ['Australia', 'scientific article published on 01 October 2008', []],
#  ['Australia', 'scientific article published on 01 April 1988', []],
#  ['AUSTRALIA', None, []],
#  ['Australia', None, []],
#  ['Australia', None, []],
#  ['Australia', None, []],
#  ['Israel', 'sovereign state in western Asia', ['Country']],
#  ['Jacob',
#   'Patriarch son of Isaac, God renamed him as Israel, Father of the Israelites',
#   ['FictionalCharacter']],
#  ['Israel', 'male given name', []],
#  ['Israel', 'Wikimedia disambiguation page', []],
#  ['Jozef Israëls', 'Dutch painter (1824-1911)', ['Artist']],
#  ['Jacob in Islam', 'Prophet and son of Isaac in Islam', ['Person']],
#  ['7507 Israel', 'asteroid', []],
#  ['Isaac Israëls',
#   'Dutch painter associated with Amsterdam Impressionism (1865-1934)',
#   ['Artist']],
#  ['Israel', 'family name', []],
#  ['Israel', 'Spanish footballer', []],
#  ['UTC+02:00', 'identifier for a time offset from UTC of +2', []],
#  ['Israel Museum',
#   'national museum of the state of Israel in Jerusalem',
#   ['Museum']],
#  ['Israel',
#   'original song written and composed by Sioux, Sverein, McGeoch, Clarke',
#   ['Song']],
#  ['Israel',
#   'theatrical production (Teatro di Torino di Riccardo Gualino)',
#   []],
#  ['Israel', 'male given name (ישראל)', []],
#  ['Israel', 'vocal track by Bee Gees from the 1971 album Trafalgar', []],
#  ['Israel / Dearest', '1972 Dutch 7" single by Bee Gees', []],
#  ['Israel',
#   'unincorporated community in Preston County, West Virginia, United States',
#   []],
#  ['Israel Defense Forces',
#   'combined military forces of Israel',
#   ['MilitaryUnit']],
#  ['Israel', 'original song written and composed by Barry Gibb', ['Song']],
#  ['Israel', 'album by Kai Winding and J. J. Johnson', ['Album']],
#  ['Israel',
#   'vocal track by Siouxsie and the Banshees; stand-alone single track',
#   []],
#  ['Israel', 'settleement in Chalchihuitán, Ciapas, Mexico', []],
#  ['Israel', 'settlement in Ocosingo, Chiapas, Mexico', []],
#  ['Israel', 'painting by Roger Huyssen', []],
#  ['Israel', 'newspaper', []],
#  ['Israel', 'original instrumental composed by John Carisi', []],
#  ['Israel', 'play', []],
#  ['Israel / Lion in Winter', 'Portuguese 7" single by The Bee Gees', []],
#  ['Daniel Israel', 'German artist', []],
#  ['Israel', 'poem', []],
#  ['Israel', 'scientific article published on 01 February 2020', []],
#  ['Israel', None, []],
#  ['Tetelestai', 'album by Diante do Trono', ['Album']],
#  ['Israel', 'family', []],
#  ['Israel', 'bishop of Caucasian Albania', []],
#  ['Israel', '1949 film by Erik Balling, Mogens Wieth', []],
#  ['I.  Feinmesser', None, []],
#  ['Israel', 'Patriarch of the Church of the East in 961', ['owl#Thing']],
#  ['Israel', 'Wikinews article', []],
#  ['Israel', 'scientific article published on 01 April 1969', []],
#  ['Israel', 'journal article; published in Nature on 1976-7', []],
#  ['Israel', 'scientific article published on 01 June 1989', []],
#  ['Israel', 'journal article; published in Nature on 1977-1', []],
#  ['Israel', '2016 documentary film', []],
#  ['Israel', 'scientific article published on 01 December 2008', []],
#  ['Israel', 'scientific article published in Nature', []],
#  ['Israel national football team',
#   "men's national association football team representing Israel",
#   ['SoccerClub']],
#  ['Israeli Central Bureau of Statistics',
#   "Israel's principal government institution in charge of statistics and census data",
#   []],
#  ['Israel Football Association',
#   'association football governing body of Israel',
#   []],
#  ['Zambia', 'sovereign state in Southern Africa', ['Country']],
#  ['Zambia national football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['2016 Zambian general election', None, ['Election']],
#  ['Zambian kwacha', 'official currency of Zambia', ['Currency']],
#  ['Zambia Super League', None, ['SoccerLeague']],
#  ['Zambia at the Olympics',
#   'country entered in olympic  games',
#   ['owl#Thing']],
#  ["Chaplin's Barbet", 'species of bird', []],
#  ['Zambia at the 2016 Summer Olympics', None, []],
#  ['National Assembly', 'legislative body of Zambia', ['Legislature']],
#  ['Zambia at the 2012 Summer Olympics',
#   'List of participants from Sambia',
#   []],
#  ['Zambia at the 2008 Summer Olympics', None, []],
#  ['Zambia national under-20 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Zambian Government',
#   'Is the executive of the National Assembly for Zambia',
#   []],
#  ['Democratic Republic of the Congo–Zambia border',
#   'international border',
#   []],
#  ["Zambia women's national football team",
#   'national association football team',
#   ['SoccerClub']],
#  ['Zambia at the 1996 Summer Olympics', None, []],
#  ['Zambia at the 1988 Summer Olympics', None, ['Event']],
#  ['Malawi–Zambia border', 'international border', []],
#  ['Zambia at the 1984 Summer Olympics', None, []],
#  ['Zambia at the 2004 Summer Olympics',
#   'List of participants from Zambia',
#   []],
#  ['Zambia at the 2000 Summer Olympics',
#   'List of participants from Zambia',
#   []],
#  ['2015 Zambian presidential election', None, ['Election']],
#  ['Namibia–Zambia border', 'international border', []],
#  ['Zambia at the 1980 Summer Olympics', None, ['Event']],
#  ['Zambia at the 1992 Summer Olympics', None, []],
#  ['Zambia at the 1968 Summer Olympics', None, []],
#  ['Zambia at the 1972 Summer Olympics', None, []],
#  ['Large-scale grass lizard', 'species of reptile', []],
#  ['Zambian pound',
#   'Coin unit of Zambia since its independence, occurred in October 24th of 1964, until January 16th of 1968',
#   ['Currency']],
#  ['Zambia–Zimbabwe border', 'international border', []],
#  ['Zambia mental health country profile.',
#   'scientific article published on February 2004',
#   []],
#  ['Zambia International Badminton Championships',
#   'badminton championships',
#   []],
#  ['Botswana–Zambia border', 'international border', []],
#  ['2011 Zambian general election', 'general election', ['Election']],
#  ['Zambian legislative election', None, []],
#  ['Zambian teachers: what do they know about epilepsy and how can we work with them to decrease stigma?',
#   'scientific article',
#   []],
#  ["Zambian women's experiences of urban maternity care: results from a community survey in Lusaka.",
#   'scientific article published on April 2003',
#   []],
#  ["Zambian health care workers' knowledge, attitudes, beliefs, and practices regarding epilepsy.",
#   'scientific article',
#   []],
#  ['Zambian Defence Force',
#   'combined military forces of Zambia',
#   ['MilitaryUnit']],
#  ['Tanzania–Zambia border', 'international border', []],
#  ['2008 Zambian presidential election', 'election', ['Election']],
#  ['2006 Zambian general election', 'election', ['Election']],
#  ['Mozambique–Zambia border', 'international border', []],
#  ['Angola–Zambia border', 'international border', []],
#  ['Zambia nurse (Kitwe, Zambia : 1978)', 'journal', []],
#  ['Zambian Air Force',
#   "air warfare branch of Zambia's military",
#   ['MilitaryUnit']],
#  ['Zambian Airways', 'airline in Zambia', ['Airline']],
#  ['Ambassador of Zambia', None, []],
#  ['Zambia national under-17 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Minister of Foreign Affairs', 'Minister of Foreign Affairs of Zambia', []],
#  ['Bermuda',
#   'British overseas territory in the North Atlantic Ocean',
#   ['Country']],
#  ['bermuda shorts', 'knee-length walking shorts for men or women', []],
#  ['Bermuda', 'Wikimedia disambiguation page', ['owl#Thing']],
#  ['Bermuda', '1951 song by The Bell Sisters', ['Song']],
#  ['Bermuda', 'American band', []],
#  ['Bermuda', 'band from Iceland', []],
#  ['Bermuda', '1912 silent short film', []],
#  ['Bermuda', 'ship built in 2010', []],
#  ['Bermuda', 'street in Zaandam, the Netherlands', []],
#  ['Bermuda national football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Bermuda Triangle',
#   'region in the western part of the North Atlantic Ocean',
#   ['BodyOfWater']],
#  ['Cynodon hirsutus', 'species of planet', []],
#  ['Bermuda national cricket team', 'National cricket team', ['CricketTeam']],
#  ['Bermuda at the Olympics',
#   'Participation of athletes from Bermuda in the Olympic Games',
#   ['owl#Thing']],
#  ['Bermuda Dunes', 'Place in Riverside County, California, United States', []],
#  ['Azores High', None, ['owl#Thing']],
#  ['Bermuda Hogges', 'association football club', ['SoccerClub']],
#  ['Bermuda Petrel', 'species of bird', []],
#  ['Bermuda at the 2016 Summer Olympics', None, []],
#  ['L.F. Wade International Airport',
#   "international airport serving St. David's Island, Bermuda",
#   ['Airport']],
#  ['Bermuda at the 2018 Winter Olympics', None, []],
#  ['Bermuda at the 2014 Winter Olympics', None, []],
#  ['Bermuda at the 2012 Summer Olympics', None, []],
#  ['Bermuda Run', 'town in North Carolina, United States', []],
#  ['Bermuda at the 2008 Summer Olympics', None, []],
#  ['Bermuda rig',
#   'configuration of mast and rigging for a type of sailboat',
#   []],
#  ['Bermuda at the 2010 Winter Olympics', None, []],
#  ['Bermuda at the 1976 Summer Olympics',
#   'country entered in olympic summer games',
#   []],
#  ['Bermuda Football Association',
#   'The official football (soccer) organization in Bermuda.',
#   []],
#  ['Bermuda at the 2006 Winter Olympics', None, []],
#  ['Sabal bermudana', 'species of plant', []],
#  ['Bermuda No. 2, The Schooner', 'drawing by Charles Demuth', []],
#  ['Bermuda at the 1936 Summer Olympics', 'wikimedia list article', []],
#  ['Bermuda Bowl', None, []],
#  ['Bermuda at the 1998 Winter Olympics', None, []],
#  ['Bermuda at the 2002 Winter Olympics', None, []],
#  ['Bermuda at the 1994 Winter Olympics', None, []],
#  ['Kyphosus sectatrix', 'species of fish', ['Fish']],
#  ['Bermuda at the 1972 Summer Olympics',
#   'country entered in  olympic summer games',
#   []],
#  ['Bermuda at the 1952 Summer Olympics',
#   'country entered in olympic summer  games',
#   []],
#  ['Bermuda blue angelfish', 'species of fish', []],
#  ['Bermuda at the 1992 Winter Olympics',
#   "participant in '92 Olympic Games",
#   []],
#  ['Bermuda Night Heron', 'extinct heron', []],
#  ['Bermuda rock skink', 'species of reptile', []],
#  ['Bermuda at the 1992 Summer Olympics', None, []],
#  ['Bermuda at the 2000 Summer Olympics',
#   'country entered in olympic summer  games',
#   []],
#  ['Bermuda at the 1984 Summer Olympics', None, []],
#  ['Bermuda at the 1988 Summer Olympics', None, []],
#  ['Bermuda at the 1968 Summer Olympics', None, []],
#  ['Bermuda at the 1996 Summer Olympics', None, []],
#  ['Poland', 'sovereign state in Central Europe', []],
#  ['Gregory A. Poland', 'American physician and vaccinologist', ['owl#Thing']],
#  ['Poland', 'constituency of the European Parliament', []],
#  ['Poland', 'village in Ohio, United States', []],
#  ['Poland', 'Wikimedia disambiguation page', []],
#  ['Poland', 'town in Maine, US', []],
#  ['Polish', 'breed of chicken', []],
#  ['Padovana chicken', 'breed of chicken', []],
#  ['Polish–Lithuanian Commonwealth',
#   'dualistic state, a bi-confederation, of Poland and Lithuania ruled by a common monarch, who was both the King of Poland and the Grand Duke of Lithuania',
#   ['Country']],
#  ['Poland', 'family name', []],
#  ['Poland - The Warsaw Concert', 'album by Tangerine Dream', ['Album']],
#  ['Poland', 'town of the United States', []],
#  ['Poland', 'village in Herkimer County, New York, United States', []],
#  ['Poland', 'village in Kiribati', []],
#  ['Poland national football team',
#   "men's national association football team representing Poland",
#   ['SoccerClub']],
#  ['Poland', 'badminton player', []],
#  ['Poland', 'unincorporated community in Clay County, Indiana', []],
#  ['Poland', 'unincorporated community in Brown County, Wisconsin', []],
#  ['Poland', 'art work', ['Artwork']],
#  ['Poland', 'novel by James A. Michener', ['Book']],
#  ['Poland', '1983 edition', []],
#  ['National Foundation for Environmental Protection', None, []],
#  ['Poland', None, []],
#  ['Komisja Specjalna do Walki z Nadużyciami i Szkodnictwem Gospodarczym',
#   None,
#   []],
#  ['Poland',
#   'human settlement in Androscoggin County, Maine, United States of America',
#   []],
#  ['Rada Strategii Społeczno-Gospodarczej przy Radzie Ministrów', None, []],
#  ['Centralne Towarzystwo Rolnicze', None, []],
#  ['Poland', 'scientific article published on 01 January 1988', []],
#  ['Poland', 'scientific article published on 01 October 1987', []],
#  ['Poland', None, []],
#  ['Poland', 'scientific article published on 01 September 1987', []],
#  ['Poland', 'article', []],
#  ['Invasion of Poland',
#   '1939 military invasion of Poland, first campaign of World War II in Europe',
#   ['MilitaryConflict']],
#  ['Poland national under-21 football team',
#   'sportsteam of men',
#   ['SoccerClub']],
#  ['Czech Republic–Poland border',
#   'separates the state territories of the two States',
#   []],
#  ['Mazurek Dąbrowskiego',
#   'National Anthem of Poland known as Mazurek Dąbrowskiego, Poland Is Not Yet Lost, or Song of the Polish Legions in Italy',
#   ['owl#Thing']],
#  ['Poland national under-20 football team', 'sports team', ['SoccerClub']],
#  ['Polandball', 'user-generated internet meme', []],
#  ['Poland in the Eurovision Song Contest',
#   'Participation of Poland in a song competition "Eurovision"',
#   []],
#  ['Poland national under-19 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Germany–Poland border', 'international border', []],
#  ['Poland national handball team', None, []],
#  ["Poland women's national handball team", None, []],
#  ['Poland national under-17 football team', 'sports team', ['SoccerClub']],
#  ['Poland at the Olympics',
#   'Participation of athletes from Poland in the Olympic Games',
#   ['owl#Thing']],
#  ['Poland–Slovakia border',
#   'separates the state territories of the two States',
#   []],
#  ["Poland men's national volleyball team",
#   "men's national volleyball team representing Poland",
#   []],
#  ['Belarus–Poland border', 'Border between Belarus and Poland', []],
#  ['Poland–Ukraine border', 'border between Poland and Ukraine', []],
#  ["Poland women's national football team",
#   "women's national association football team representing Poland",
#   ['SoccerClub']],
#  ['South Korea', 'sovereign state in East Asia', ['Country']],
#  ['South Korea', 'journal article; published in Nature on 2015-08-12', []],
#  ['South Korea', 'journal article; published in Nature on 2005-10-01', []],
#  ['South Korea', '2015 scholarly article published in Nature', []],
#  ['South Korea',
#   '2015 scholarly article published in Nature vol 519, issue 7544',
#   []],
#  ['South Korea', '1966 scholarly article published in Adelphi Papers', []],
#  ['South Korea', 'scholarly article', []],
#  ['South Korea national football team',
#   "men's national association football team representing South Korea",
#   ['SoccerClub']],
#  ['South Korean won',
#   'official currency of the Republic of Korea',
#   ['Currency']],
#  ['South Korea national under-20 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Republic of Korea Navy',
#   "naval warfare branch of South Korea's military",
#   ['MilitaryUnit']],
#  ['South Korea national under-23 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Republic of Korea Army',
#   "land warfare branch of South Korea's military",
#   ['MilitaryUnit']],
#  ['2020 South Korean legislative election',
#   '15 April 2020 legislative election in South Korea',
#   ['Election']],
#  ['Republic of Korea Air Force',
#   "air warfare branch of South Korea's military",
#   ['MilitaryUnit']],
#  ["South Korea women's national association football team",
#   "women's national association football team representing South Korea",
#   ['SoccerClub']],
#  ['Republic of Korea Armed Forces',
#   'combined military forces of South Korea',
#   ['MilitaryUnit']],
#  ['flag of South Korea', 'flag', []],
#  ['South Korea national handball team', None, []],
#  ['South Korea national under-17 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['South Korea at the Olympics',
#   'country entered in  olympic  games',
#   ['owl#Thing']],
#  ['2019–20 COVID-19 outbreak in South Korea',
#   'viral outbreak in South Korea',
#   []],
#  ['2012 South Korean presidential election', None, ['Election']],
#  ['South Korea at the 2016 Summer Olympics', None, []],
#  ["South Korea women's national handball team", None, []],
#  ['Government of South Korea', 'National government of South Korea', []],
#  ['South Korean time trade-off values for EQ-5D health states: modeling with observed values for 101 health states.',
#   'scientific article',
#   []],
#  ['2016 South Korean legislative election', None, ['Election']],
#  ['2017 South Korean presidential election', None, ['Election']],
#  ['National Intelligence Service',
#   'intelligence agency of South Korea',
#   ['GovernmentAgency']],
#  ['South Korea at the 2012 Summer Olympics', None, []],
#  ["South Korea men's national volleyball team",
#   "men's national volleyball team representing\xa0South Korea",
#   []],
#  ['Republic of Korea Marine Corps',
#   "amphibious warfare branch of South Korea's military",
#   ['MilitaryUnit']],
#  ['South Korea at the 2010 Winter Olympics', None, []],
#  ['music of South Korea',
#   'music and musical traditions of South Korea',
#   ['owl#Thing']],
#  ["South Korea women's national volleyball team",
#   "women's national volleyball team representing\xa0South Korea",
#   []],
#  ['South Korea at the 2018 Winter Olympics', None, ['owl#Thing']],
#  ['South Korea national basketball team',
#   "men's national basketball team representing\xa0South Korea",
#   []],
#  ['South Korea at the 2014 Winter Olympics', None, []],
#  ['South Korea national badminton team', 'national badminton team', []],
#  ['South Korean Olympic Committee', 'sports body of South Korea', []],
#  ['2007 South Korean presidential election',
#   'Presidential election in South Korea',
#   ['Election']],
#  ['South Korea at the 2008 Summer Olympics',
#   'list of participants from South Korea',
#   []],
#  ["South Korea men's national ice hockey team", 'national sports team', []],
#  ['culture of South Korea',
#   'pattern of human activity and symbolism associated with South Korea and its people',
#   ['owl#Thing']],
#  ['South Korea national rugby union team', 'rugby union team', ['RugbyClub']],
#  ["South Korea women's national basketball team",
#   "women's national basketball team representing\xa0South Korea",
#   []],
#  ['South Korean Badminton Championships', 'badminton championships', []],
#  ['South Korea at the 2002 Winter Olympics',
#   'country entered in olympic  winter games',
#   []],
#  ['Jae-Hyuk Yang', 'researcher', []],
#  ['Fiji', 'island sovereign state in Oceania', ['Country']],
#  ['HMS Fiji', 'cruiser', ['Ship']],
#  ['Fiji', 'human settlement in Saudi Arabia', []],
#  ['Phi Gamma Delta', 'fraternity', ['owl#Thing']],
#  ['Fiji', 'Wikimedia disambiguation page', []],
#  ['Fiji', 'open source image processing software', ['Software']],
#  ['Fiji', 'song by Taco Hemingway', []],
#  ['Fiji', 'French writer', []],
#  ['Fiji', 'print in the National Gallery of Art (NGA 62172)', []],
#  ['Fiji', None, []],
#  ['Fiji', 'journal article; published in Nature on 2006-3', []],
#  ['Fiji', 'scientific article published on 01 November 1987', []],
#  ['Fiji', 'scientific article published on 01 June 1982', []],
#  ['Fiji national rugby union team', 'national sports team', []],
#  ['Fijian',
#   'Austronesian language of the Malayo-Polynesian family spoken in Fiji',
#   ['Language']],
#  ['Fiji: an open-source platform for biological-image analysis.',
#   'scientific article',
#   []],
#  ['Fiji national football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Fiji Hindi',
#   'language spoken by most Fijian citizens of Indian descent',
#   ['Language']],
#  ['Fijian dollar', 'currency of Fiji', ['Currency']],
#  ['Fiji Premier League',
#   'top division of the Fiji Football Association in Fiji',
#   ['SoccerLeague']],
#  ['Fiji Airways', 'national airline of Fiji', ['Airline']],
#  ['Fiji Labour Party', 'political party', []],
#  ['Fiji at the Olympics',
#   'Participation of athletes from Fiji in the Olympic Games',
#   ['owl#Thing']],
#  ['Fiji Football Association', 'sports governing body', []],
#  ['Fiji Hindi Wikipedia', 'Fiji', []],
#  ['Fiji Crested Iguana', 'species of reptile', []],
#  ['Accipiter rufitorques', 'species of bird', []],
#  ['Fiji national rugby union team (sevens)', None, ['RugbyClub']],
#  ['Fiji Parrotfinch', 'species of finches', []],
#  ['Fiji Banded Iguana', 'species of reptile', []],
#  ['Fiji Petrel', 'species of bird', []],
#  ['Fiji First Party', 'political party in Fiji', ['PoliticalParty']],
#  ['Template:Fj icon', 'Wikimedia template', []],
#  ['Fiji at the 2016 Summer Olympics', None, ['owl#Thing']],
#  ['Fijians', 'ethnic group', ['EthnicGroup']],
#  ['Fiji Woodswallow', 'species of bird', []],
#  ['Fijian Monkey-faced Bat', 'species of mammal', []],
#  ['Fiji Shrikebill', 'species of bird', []],
#  ['Fiji at the 2012 Summer Olympics', None, []],
#  ['Fiji snake', 'species of reptile', []],
#  ['Fiji Sea', None, []],
#  ['Republic of Fiji Military Forces',
#   'combined military forces of Fiji',
#   ['MilitaryUnit']],
#  ['Fiji at the 2008 Summer Olympics',
#   'participation details and results of team from Fiji',
#   []],
#  ['Fiji National University', None, ['University']],
#  ['Fijian mastiff bat', 'Species of bat found in Fiji and Vanuatu', []],
#  ['Fiji national cricket team', 'sports team', ['CricketTeam']],
#  ['Template:Lang-hif', 'Wikimedia template', []],
#  ['Candoia bibroni', 'species of reptile', []],
#  ['Fiji Link', 'Fijian airline', ['Airline']],
#  ['Fiji at the 2000 Summer Olympics', None, []],
#  ['Czech Republic', 'sovereign state in Central Europe', ['Country']],
#  ['Czech Republic', 'constituency of the European Parliament', []],
#  ['Kostelec nad Černými lesy', None, []],
#  ['Czech Republic',
#   'member state of the Czech and Slovak Federal Republic (1990–1992)',
#   []],
#  ['Czech Republic', 'Wikimedia disambiguation page', []],
#  ['Czech Republic', 'iGEM 2015 team', []],
#  ['Czech Republic', None, []],
#  ['Czech Republic', None, []],
#  ['Czech Republic', None, []],
#  ['Czech Republic', None, []],
#  ['Czech Republic', None, []],
#  ['CZECH REPUBLIC', None, []],
#  ['Czech Republic national football team',
#   "men's national association football team representing the Czech Republic",
#   ['SoccerClub']],
#  ['National Gallery in Prague',
#   'Art gallery in Prague, Czech Republic',
#   ['Museum']],
#  ['Czech Republic national under-21 football team',
#   'national under-21 football team of the Czech Republic',
#   ['SoccerClub']],
#  ['2017 Czech legislative election',
#   'All 200 seats of the Chamber of Deputies, lower house of the Parliament, were available for the election.',
#   ['Election']],
#  ['Czech Republic national under-19 football team',
#   'sports team',
#   ['SoccerClub']],
#  ['Czech Republic national under-17 football team',
#   'sports team',
#   ['SoccerClub']],
#  ["Czech Republic men's national ice hockey team",
#   "men's national ice hockey team representing the Czech Republic",
#   []],
#  ["Czech Republic women's national football team",
#   "women's national association football team representing the Czech Republic",
#   ['SoccerClub']],
#  ['Czech Republic in the Eurovision Song Contest',
#   'Czech Republic in the Eurovision Song Contest',
#   []],
#  ['Czech Republic national under-20 football team',
#   'national association football team',
#   []],
#  ['Czech Republic national under-18 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Czech Republic motorcycle Grand Prix',
#   'motorcycle race held in the Czech Republic',
#   []],
#  ['Czech Republic national handball team', None, []],
#  ['Czech Republic at the Olympics',
#   'Participation of athletes from the Czech Republic in the Olympic Games',
#   ['owl#Thing']],
#  ['Czech Republic Fed Cup team',
#   'Fed Cup team representing the Czech Republic',
#   []],
#  ['Czech Republic national basketball team',
#   'national basketball team representing the Czech Republic',
#   []],
#  ['Czech Republic-Poland border crossings', None, []],
#  ['Czech Air Force',
#   'aerial warfare branch of the Czech Republic and Czechoslovakia',
#   ['MilitaryUnit']],
#  ['Czech Republic national futsal team',
#   'national sports team',
#   ['owl#Thing']],
#  ["Czech Republic men's national volleyball team",
#   "men's national volleyball team representing the\xa0Czech Republic",
#   []],
#  ['Czech Republic at the 2012 Summer Olympics', None, []],
#  ['Czech Republic at the 2016 Summer Olympics', None, []],
#  ['Czech Republic at the 2010 Winter Olympics', None, []],
#  ["Czech Republic women's national basketball team",
#   "women's national basketball team representing the\xa0Czech Republic",
#   []],
#  ['Leipzig Book Fair', 'recurring event', ['owl#Thing']],
#  ['Czech Republic Davis Cup team',
#   'Davis Cup team representing the Czech Republic',
#   []],
#  ['Czech Republic at the 2018 Winter Olympics', None, []],
#  ['Czech Republic at the 2014 Winter Olympics', None, []],
#  ["Czech Republic women's national volleyball team",
#   "women's national volleyball team representing the\xa0Czech Republic",
#   []],
#  ["Czech Republic women's national handball team",
#   "women's national handball team representing the Czech Republic",
#   []],
#  ['Czech Republic at the 2008 Summer Olympics', None, []],
#  ['Czech Republic at the 2004 Winter Olympics',
#   'country entered in olympic summer games',
#   ['owl#Thing']],
#  ['Czech Republic–Germany border',
#   'Disconnects the territories of Germany and Czechia',
#   []],
#  ['Czech Republic at the 2006 Winter Olympics', None, []],
#  ['Czech Republic at the 2002 Winter Olympics',
#   'country entered in olympic winter games',
#   []],
#  ['Czech Republic at the 2000 Summer Olympics', None, []],
#  ['Czech Republic at the 1998 Winter Olympics',
#   'country entered in olympic winter games',
#   []],
#  ['Lebanon', 'sovereign state in Western Asia', ['Country']],
#  ['Lebanon', 'county seat of Lebanon County, Pennsylvania, United States', []],
#  ['Lebanon', 'city in Grafton County, New Hampshire, United States', []],
#  ['Lebanon', 'city in Wilson County, Tennessee, United States', []],
#  ['Lebanon', 'city in southwestern Ohio, United States', []],
#  ['Lebanon', 'city in Laclede County, Missouri, United States', []],
#  ['Lebanon', 'city in Indiana, United States', []],
#  ['Lebanon', 'city in Oregon, USA', []],
#  ['Lebanon', 'city in Marion County, Kentucky, United States', []],
#  ['Lebanon', 'town in New London County, Connecticut, United States', []],
#  ['Lebanon', 'city in St. Clair County, Illinois, United States', []],
#  ['Lebanon', 'Wikimedia disambiguation page', []],
#  ['Lebanon', 'town in Russell County, Virginia, United States', []],
#  ['Lebanon', '2009 film by Samuel Maoz', ['Film']],
#  ['Lebanon', 'city in Smith County, Kansas, United States', []],
#  ['Lebanon', 'town in Nebraska, United States', []],
#  ['Lebanon', 'borough of New Jersey', []],
#  ['Lebanon', 'town in South Dakota, United States of America', []],
#  ['Lebanon', 'town in Maine', []],
#  ['Lebanon',
#   'unincorporated community in Marshall County, Oklahoma, United States',
#   []],
#  ['Lebanon', 'town in New York, United States', []],
#  ['Lebanon',
#   'human settlement in Dodge County, Wisconsin, United States of America',
#   []],
#  ['Lebanon', 'civil town in Waupaca County, Wisconsin', []],
#  ['Lebanon', None, []],
#  ['Lebanon',
#   "2006 award-winning gay pornographic film directed by Collin O'Neal",
#   ['owl#Thing']],
#  ['Lebanon', 'episode of Supernatural (S14 E13)', []],
#  ['Lebanon', 'painting by Nabil Kanso', ['Artwork']],
#  ['Lebanon',
#   'New Jersey Transit railroad station on the Raritan Valley Line in Lebanon, New Jersey',
#   ['Station']],
#  ['Lebanon', 'human settlement in Colorado, United States of America', []],
#  ['Lebanon', 'human settlement in Texas, United States of America', []],
#  ['Lebanon',
#   "station on Nashville's regional rail line, the Music City Star",
#   ['Station']],
#  ['Eastern European Time', 'time zone', []],
#  ['Lebanon', None, []],
#  ['Lebanon', None, ['Building']],
#  ['Lebanon', None, []],
#  ['LEBANON', 'Liner built in Aberdeen in 1907', []],
#  ['Lebanon', 'print in the National Gallery of Art (NGA 145324)', []],
#  ['Lebanon', 'Congressional Research Service report', []],
#  ['Lebanon', 'print in the National Gallery of Art (NGA 63329)', []],
#  ['Lebanon', None, []],
#  ['Lebanon', 'scientific article published on 01 January 2007', []],
#  ['Lebanon', 'Bath and North East Somerset, Somerset, BA2', []],
#  ['1982 Lebanon War',
#   '1982 war between Israel and forces in Lebanon',
#   ['MilitaryConflict']],
#  ['Eastern European Summer Time',
#   'daylight savings time zone used in eastern Europe (UTC+3)',
#   []],
#  ['Lebanon County',
#   'county in Pennsylvania, United States of America',
#   ['AdministrativeRegion']],
#  ['Lebanon national football team',
#   "men's national association football team representing Lebanon",
#   ['SoccerClub']],
#  ['Cedrus libani', 'species of plant', []],
#  ['Lebanon at the Olympics',
#   'Participation of athletes from Lebanon in the Olympic Games',
#   []],
#  ['Lebanon Junction',
#   'human settlement in Bullitt County, Kentucky, United States of America',
#   []],
#  ['Rising Sun-Lebanon', 'census-designated place in Delaware', []],
#  ['Japan',
#   'sovereign state in East Asia, situated on an archipelago of five main and over 6,800 smaller islands',
#   ['Country']],
#  ['Tokugawa Shogunate',
#   'The dynastic military regency which ruled Japan in the name of the emperor between 1600 and 1868; the territory held by the regency',
#   ['Country']],
#  ['occupation of Japan',
#   'Allied occupation of Japan following WWII',
#   ['Country']],
#  ['Japan', 'English new wave band', ['Band']],
#  ['Japan', 'Wikimedia disambiguation page', []],
#  ['Japanese', 'East Asian language', ['Language']],
#  ['Japanese Wikipedia', 'Japanese language edition of Wikipedia', ['Website']],
#  ['J-pop',
#   'musical genre that entered the musical mainstream of Japan in the 1990s',
#   ['MusicGenre']],
#  ['Japanese people', 'ethnic group native to Japan', ['EthnicGroup']],
#  ['history of Japan', 'aspect of history', ['owl#Thing']],
#  ['UTC+09:00', 'identifier for a time offset from UTC of +9', []],
#  ['Japón', '2002 film by Carlos Reygadas', ['Film']],
#  ['Empire of Japan', 'monarchy between 1868–1947', ['Country']],
#  ['anime', 'animation produced in Japan', ['owl#Thing']],
#  ['Japan', None, []],
#  ['Japan', 'manga by Buronson', ['Manga']],
#  ['Gensuibaku Kinshi Nihon Kokumin Kaigi', None, []],
#  ['Japan', 'village in Kudus, Central Java Province, Indonesia', []],
#  ['Japan', None, ['Band']],
#  ['Kamagaya-shi', None, []],
#  ['Japan', '2008 American film by Fabien Pruvot', ['Film']],
#  ['Japan', 'village in Magelang, Central Java Province, Indonesia', []],
#  ['Japan', 'unincorporated community in Pennsylvania, United States', []],
#  ['Rekishi Kenkyūkai', None, []],
#  ['Wajima-shi', None, []],
#  ['Japan', 'map edition', []],
#  ['Japan', 'Famous Dex single', []],
#  ['Japan', 'painting by Sam Francis', []],
#  ['Japan', 'painting by Eugène Brands', []],
#  ['Zaikai Kenkyūjo', None, []],
#  ['Japan Standard Time', 'time zone', []],
#  ['Japan', 'desa in Indonesia (Jawa Tengah (2))', []],
#  ['Japan', 'desa in Indonesia (Jawa Timur (3))', []],
#  ['Japan', 'desa in Indonesia (Jawa Tengah (1))', []],
#  ['Japan', 'desa in Indonesia (Jawa Timur (4))', []],
#  ['Japan', 'desa in Indonesia (Jawa Timur (1))', []],
#  ['Japan', 'manga series by Eiji Ohtsuka with art by Mami Itoh', ['Manga']],
#  ['Japan', 'desa in Indonesia (Jawa Timur (2))', []],
#  ['Japan', None, []],
#  ['Japan', 'village in Ponorogo, East Java Province, Indonesia', []],
#  ['manga', 'comics created in Japan', ['owl#Thing']],
#  ['Japan national football team chakhchokha',
#   "men's national association football team representing Japan",
#   ['SoccerClub']],
#  ['Monogatari Kenkyūkai', None, []],
#  ['Makurazaki-shi', None, []],
#  ['Fukagawa-shi', None, []],
#  ['Fujisawa-shi', None, []],
#  ['Komagane-shi', None, []],
#  ['Kokumin Keizai Kenkyū Kyōkai', None, []],
#  ['Saiki-shi', None, []],
#  ['Japan', '1982 album by the British band Japan', ['Album']],
#  ['New Zealand',
#   'sovereign state in Oceania, situated on two main and around 600 smaller islands in the southwestern Pacific Ocean',
#   ['Country']],
#  ['New Zealand', 'Wikimedia disambiguation page', []],
#  ['386622 New Zealand', 'asteroid', []],
#  ["Rosa 'New Zealand'", 'rose cultivar', []],
#  ['New Zealand', 'painting by Fred Taylor', []],
#  ['New Zealand', '(Vicariate Apostolic); Historical', []],
#  ['New Zealand', 'hamlet in Hilmarton, Wiltshire, England', ['Settlement']],
#  ['New Zealand', 'suburb of Derby, Derbyshire, England', []],
#  ['Shaky Isles', 'nickname for New Zealand', []],
#  ['New Zealand',
#   'hamlet in Aylesbury, Buckinghamshire, England',
#   ['Settlement']],
#  ['New Zealand', 'duplicated disambiguation page', []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'scientific article published in November 1932', []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New zealand', 'scientific article published on 01 October 1987', []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'scholarly article about divorce in New Zealand', []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'scientific article published in December 1934', []],
#  ['New Zealand', 'scientific article published in December 1936', []],
#  ['New Zealand', 'journal article; published in Nature on 1977-9', []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'scientific article published on 01 March 1987', []],
#  ['New zealand', 'scientific article published on 01 November 1987', []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'scientific article published in September 1966', []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'scientific article published in Nature', []],
#  ['New Zealand', 'scientific article published in September 1907', []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['New Zealand', None, []],
#  ['NEW ZEALAND', None, []],
#  ['New Zealand', 'scientific article published in March 1928', []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'journal article; published in Nature on 2015-08-12', []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'scientific article published on 01 June 1993', []],
#  ['New Zealand', 'scientific article published in December 1906', []],
#  ['New Zealand', None, []],
#  ['New Zealand', 'scientific article published in March 1931', []],
#  ['New Zealand', None, []],
#  ['Switzerland', 'sovereign state in Central Europe', ['Country']],
#  ['Switzerland', 'Wikimedia disambiguation page', []],
#  ['Switzerland', 'community in Florida, United States', []],
#  ['Switzerland', 'album by rock band Electric Six', ['Album']],
#  ['Courroux', None, []],
#  ['Camorino', None, []],
#  ['Chêne-Bourg', None, []],
#  ['Augst', None, []],
#  ['Sigriswil', None, []],
#  ['Würenlingen', None, []],
#  ['Therwil', None, []],
#  ['Switzerland', 'community in South Carolina, USA', []],
#  ['Herzogenbuchsee', None, []],
#  ['Trubschachen', None, []],
#  ['Assens', None, []],
#  ['Füllinsdorf', None, []],
#  ['Morbio Inferiore', None, []],
#  ['Dübendorf', None, []],
#  ['Switzerland', '1955 short film directed by Ben Sharpsteen', []],
#  ['Plaffeien', None, []],
#  ['Seengen', None, []],
#  ['Moutier', None, []],
#  ['Zollikon', None, []],
#  ['Goldach', None, []],
#  ['Gollion', None, []],
#  ['Oftringen', None, []],
#  ['Stabio', None, []],
#  ['Büren an der Aare', None, []],
#  ['Prilly', None, []],
#  ['Switzerland', 'album by Tomasz Stańko', []],
#  ['Switzerland', 'article', []],
#  ['Catholic Church. Diocese of Sion', 'museum in Sion (Switzerland)', []],
#  ['Switzerland', 'parish in Murrindindi Shire, Victoria, Australia', []],
#  ['Switzerland', 'software', ['Software']],
#  ['Switzerland', 'poem from The poetical works of Matthew Arnold', []],
#  ['Cresciano', None, []],
#  ['Reichenburg', None, []],
#  ['Neunkirch', None, []],
#  ['Switzerland', 'scientific article published on 01 January 1988', []],
#  ['Switzerland', 'scientific article published on 01 March 1989', []],
#  ['Switzerland', 'scientific article published on 01 April 1988', []],
#  ['Switzerland', None, []],
#  ['Switzerland', 'scientific article published on 01 January 2008', []],
#  ['Switzerland', None, []],
#  ['Switzerland', 'scientific article published in Nature', []],
#  ['Switzerland', 'scientific article published on 01 January 1932', []],
#  ['Switzerland', None, []],
#  ['Swiss national football team',
#   "men's national association football team representing Switzerland",
#   ['SoccerClub']],
#  ['Switzerland national under-21 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Switzerland County',
#   'county in Indiana, United States',
#   ['AdministrativeRegion']],
#  ['Thailand', 'sovereign state in Southeast Asia', ['Country']],
#  ['UTC+07:00', 'Identifier for a time offset from UTC of +7', []],
#  ['Thailand', None, []],
#  ['Thailand', 'scientific article published on 01 December 2008', []],
#  ['Thailand national football team',
#   "men's national association football team representing Thailand",
#   ['SoccerClub']],
#  ['Tham Luang cave rescue',
#   'international operation to rescue a group of 12 boys and 1 adult in Tham Luang Nang Non, Thailand in 2018',
#   []],
#  ['Thailand national under-23 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Thailand national under-20 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ["Thailand women's national football team",
#   "Thailand women's national association football team",
#   ['SoccerClub']],
#  ['PTT Pattaya Open',
#   "women's tennis tournament in Pattaya, Thailand",
#   ['WomensTennisAssociationTournament']],
#  ['Burma Railway',
#   'former railway between Bangkok, Thailand, and Rangoon, Burma',
#   ['PublicTransitSystem']],
#  ['Thailand at the Olympics',
#   'Participation of athletes from Thailand in the Olympic Games',
#   ['owl#Thing']],
#  ['Thailand national futsal team', None, ['owl#Thing']],
#  ['PTT Thailand Open',
#   'tennis tournament',
#   ['WomensTennisAssociationTournament']],
#  ['Thai Badminton Championships', 'badminton championships', []],
#  ['Thailand at the 2016 Summer Olympics', None, []],
#  ['Thailand national under-17 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Thailand at the 2012 Summer Olympics', None, []],
#  ['House of Representatives', 'lower house of Thailand', ['Legislature']],
#  ['economy of Thailand', 'National economy', ['owl#Thing']],
#  ['Thailand Open Badminton Championships', 'badminton championships', []],
#  ['Sukhumvit Road', 'major road in Thailand', ['Road']],
#  ['Thailand at the 2018 Winter Olympics', None, []],
#  ['Thailand National Games', None, ['owl#Thing']],
#  ['Phahonyothin Road', 'road in Thailand', ['Road']],
#  ['Thailand at the 2008 Summer Olympics', None, []],
#  ['Thailand Masters', 'snooker tournament', []],
#  ['Thailand at the 2014 Winter Olympics', None, []],
#  ["Thailand women's national volleyball team",
#   "women's national volleyball team representing Thailand",
#   []],
#  ['Thailandepsins: bacterial products with potent histone deacetylase inhibitory activities and broad-spectrum antiproliferative activities.',
#   'scientific article',
#   []],
#  ['Thailand national badminton team', 'national badminton team', []],
#  ['Malaysia–Thailand border', 'international border', []],
#  ['E-Goverment of Thailand', None, []],
#  ['Thailand national ice hockey team', None, []],
#  ['Hipposideros halophyllus', 'species of mammal', []],
#  ['Thailand at the 1992 Summer Olympics', None, []],
#  ['Thailand at the 2004 Summer Olympics', None, []],
#  ['Thailand at the 2000 Summer Olympics', None, []],
#  ['Thailand at the 1996 Summer Olympics', None, []],
#  ['Thailand in World War II',
#   'involvement of Thailand in World War II',
#   ['owl#Thing']],
#  ['Laos–Thailand border', 'international border', []],
#  ['Thailand at the 1988 Summer Olympics', None, []],
#  ['Thailand national basketball team', None, []],
#  ['Thailand at the 2002 Winter Olympics', None, []],
#  ['Thailand at the 2006 Winter Olympics', None, []],
#  ['Thailand Futsal League', None, ['SoccerLeague']],
#  ['Ministry of Public Health',
#   'government department responsible for public health in Thailand',
#   ['GovernmentAgency']],
#  ['Thailand at the 1984 Summer Olympics', None, []],
#  ['Thailand at the 1976 Summer Olympics', None, []],
#  ['Dalbergia cochinchinensis', 'species of plant', []],
#  ['India', 'sovereign state in South Asia', ['Country']],
#  ['British India',
#   'British rule in the Indian subcontinent, 1858–1947',
#   ['Country']],
#  ['Dominion of India',
#   'period of Indian history between 1947 and 1950',
#   ['Country']],
#  ['privacy policy',
#   "statement or a legal document that discloses some or all of the ways a party gathers, uses, discloses, and manages a customer or client's data",
#   []],
#  ['India', 'Wikimedia disambiguation page', []],
#  ['India', 'female given name', ['GivenName']],
#  ['India', 'cat owned by USA presidential Bush family', []],
#  ['Francesco Torbido', 'Italian painter (1482-1562)', ['Painter']],
#  ['India', 'American pornographic actress and rapper', ['AdultActor']],
#  ['Indiana',
#   'state of the United States of America',
#   ['AdministrativeRegion']],
#  ['Bernardino India', 'Italian painter (1528-1590)', ['owl#Thing']],
#  ['Indianapolis',
#   'city in and county seat of Marion County, Indiana, United States and the Indiana federated state capital city',
#   []],
#  ['UTC+05:30', 'identifier for a time offset from UTC of +5:30', []],
#  ['Indian National Congress', 'major political party in India', ['owl#Thing']],
#  ['Indian Ocean',
#   'ocean between Africa, Asia, Oceania and Antartica',
#   ['BodyOfWater']],
#  ['India: Matri Bhumi', '1958 film by Roberto Rossellini', ['Film']],
#  ['India', '2005 album by German band Xandria', ['Album']],
#  ['India', 'village in Transnistria, Moldova', []],
#  ['India', 'passage by Herodotus', []],
#  ['India',
#   'encyclopedic article; entry in Encyclopedia of Consumption and Waste: The Social Science of Garbage',
#   []],
#  ['India', 'mine in Atacama Region, Chile', []],
#  ['Bhāvnagar', 'human settlement in India', []],
#  ['IMO 9287699', 'ship built in 2003', []],
#  ['India', 'family name', []],
#  ['Jalor', 'human settlement in India', []],
#  ['India', 'genus of plants', []],
#  ['India ink', 'simple black or colored ink', []],
#  ['India', 'article', []],
#  ['India', 'album by Vega', ['Album']],
#  ['Jaunapura', 'human settlement in India', []],
#  ['India', 'journal article; published in Nature on 2005-7', []],
#  ['Karanja', 'mountain in India', []],
#  ['Piriyāpatna', 'human settlement in India', []],
#  ['Devaprayag', 'human settlement in India', []],
#  ['Ashapuri', 'mountain in India', []],
#  ['Mughal Sarai', 'human settlement in India', []],
#  ['Chikmagalur', 'human settlement in India', []],
#  ['Amarnāth', 'mountain in India', []],
#  ['Mudukulattūr', 'human settlement in India', []],
#  ['India', '1960 film directed by Armando Bó', []],
#  ['Gadag', 'human settlement in India', []],
#  ['India', 'ecclesiastical province of the Church of the East', []],
#  ['India', 'British Army battle honour', []],
#  ['India', None, []],
#  ['India', None, []],
#  ['India', None, []],
#  ['India', 'scientific article published in October 1911', []],
#  ['India', 'scientific article published in November 1932', []],
#  ['India', 'scientific article published in April 1910', []],
#  ['India', 'scientific article published in August 1915', []],
#  ['Jordan', 'sovereign state in Western Asia', ['Country']],
#  ['Jacob Jordaens', 'Flemish painter (1593-1678)', ['Artist']],
#  ['Luca Giordano', 'Italian painter (1634-1705)', ['Artist']],
#  ['Karl Jordan', 'German entomologist', ['owl#Thing']],
#  ['Jordan', 'family name', []],
#  ['Jordan', 'unisex given name', []],
#  ['Jordan', 'Wikimedia disambiguation page', []],
#  ['Jordan', 'city in Scott County, Minnesota, United States', []],
#  ['Jordan',
#   'town in and the county seat of Garfield County, Montana, United States',
#   []],
#  ['Jordan',
#   'municipality of the Philippines and capital of the province of Guimaras',
#   []],
#  ['Jordan', 'village in New York, United States', []],
#  ['Jordán', 'Colombian municipality of the department of Santander', []],
#  ['Jordan', 'name: given name and family name', ['GivenName']],
#  ['Jordan', 'male given name (Йордан)', []],
#  ['Jordan', 'state electoral district of Queensland, Australia', []],
#  ['Jordan', 'bishop of Poland', ['owl#Thing']],
#  ['Jordán', 'Wikimedia disambiguation page', []],
#  ['Jordan', 'town in Green County, Wisconsin, United States', []],
#  ['Jordan', 'Polish canon', []],
#  ['Jordan', 'area in the Yau Tsim Mong District of Hong Kong', []],
#  ['Jordan',
#   'fictional character from the video game The Last of Us Part II',
#   []],
#  ['Jordan',
#   'unincorporated community in Linn County, Oregon, United States',
#   []],
#  ['Jordan', 'popular avenue in Tehran, Iran', ['Road']],
#  ['Jordan', '2006 song by American musician Buckethead', []],
#  ['Dzhordan', 'Bulgarian singer', []],
#  ['Jordan',
#   'unincorporated community in Daviess County, Indiana',
#   ['Village']],
#  ['Jordan', 'river in Poland', []],
#  ['Jordan', 'former Tasmanian Legislative Council electoral division', []],
#  ['Jordan', 'Italian singer', []],
#  ['Jordan', 'electrical substation', []],
#  ['Jordan', 'occitan masculine first name', []],
#  ['Jordan', 'character from webcomic Extra Ordinary', []],
#  ['Jordan', 'unincorporated community in Fulton County, Kentucky', []],
#  ['Jordan', 'unincorporated community in Owen County, Indiana', ['Village']],
#  ['D. Jordan', 'co-writer of Give Up Your Guns', []],
#  ['Jordan', 'neighborhood in Minneapolis, United States', ['CityDistrict']],
#  ['Jordan', 'unincorporated community in Portage County, Wisconsin', []],
#  ['Jordan', None, []],
#  ['Jordan', None, []],
#  ['Jordan Seaplane Base',
#   'airport in Marion County, United States of America',
#   []],
#  ['Jordan', 'Roger (fl. c.1688)', []],
#  ['Jordan',
#   "character from 2011 film 'Good Luck Charlie, It's Christmas!'",
#   []],
#  ['Jordan', "character from 2003 film 'Eddie's Million Dollar Cook-Off'", []],
# ...
#  ['Sweden', 'unincorporated community in Jefferson County, Arkansas', []],
#  ['Nämnden för hemslöjdsfrågor', 'Swedish government agency', []],
#  ['Centrum för Arbetarhistoria',
#   'working life museum in Landskrona Municipality, Sweden',
#   []],
#  ['Sweden', 'painting by Grace Hartigan', []],
#  ['Föreningen för samhällsplanering', 'organization', []],
#  ['Sweden', 'scientific article published on 01 October 2008', []],
#  ['Sweden', 'scientific article published on 01 January 1988', []],
#  ['Sweden', None, []],
#  ['Sweden', 'periodical', []],
#  ['Sweden', 'journal article; published in Nature on 2006-1', []],
#  ['Sweden', 'journal article; published in Nature on 1977-7', []],
#  ['Sweden', 'journal article; published in Nature on 1977-5', []],
#  ['Sweden', 'scientific article published on 01 March 1969', []],
#  ['Sweden', 'journal article; published in Nature on 1976-11-01', []],
#  ['Sweden', None, []],
#  ['Sweden', 'scientific article published on 01 October 2000', []],
#  ['Sweden', 'scientific article published on 01 January 2006', []],
#  ['Sweden national football team',
#   "men's national association football team representing Sweden",
#   ['SoccerClub']],
#  ['Sweden national under-21 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Sweden Democrats', 'Swedish political party', ['PoliticalParty']],
#  ["Sweden women's national association football team",
#   "women's national association football team representing Sweden",
#   ['SoccerClub']],
#  ['Sweden in the Eurovision Song Contest', None, []],
#  ['Sweden national under-17 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Union between Sweden and Norway',
#   'personal union between Sweden and Norway 1814–1905',
#   ['Country']],
#  ['Sweden national under-19 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['history of Sweden', 'aspect of history', []],
#  ['Sweden national handball team',
#   "men's national handball team representing Sweden",
#   []],
#  ["Sweden men's national ice hockey team",
#   "men's national ice hockey team representing Sweden",
#   ['owl#Thing']],
#  ['Sweden-Finland', 'term used of Finland as a part of Sweden until 1809', []],
#  ["Sweden women's national handball team",
#   "national women's handball team representing Sweden",
#   []],
#  ['Sweden at the Olympics',
#   'Participation of athletes from Sweden in the Olympic Games',
#   ['owl#Thing']],
#  ['Sweden at the 2016 Summer Olympics', None, []],
#  ['Sweden in the Junior Eurovision Song Contest', None, []],
#  ['Sweden national under-18 football team',
#   "U-18 men's national association football team representing Sweden",
#   []],
#  ['3947 Swedenborg', 'asteroid', []],
#  ['Sweden at the 2012 Summer Olympics', None, []],
#  ['Norway–Sweden border',
#   'International border between Norway and Sweden',
#   ['owl#Thing']],
#  ['Sweden Davis Cup team', 'Davis Cup team representing Sweden', []],
#  ['Sweden at the 2010 Winter Olympics', None, []],
#  ['Sweden national basketball team',
#   "men's national basketball team representing Sweden",
#   []],
#  ['Sweden at the 2018 Winter Olympics', None, []],
#  ['Sweden at the 2014 Winter Olympics', None, []],
#  ['Indonesia',
#   'sovereign state in Southeast Asia situated on more than 17,000 islands',
#   ['Country']],
#  ['Slank', 'Indonesian rock band', ['Band']],
#  ['Indonesia', 'journal', []],
#  ['Indonesian', 'official language of Indonesia', ['Language']],
#  ['Indonesian Wikipedia', 'Indonesian version of Wikipedia', ['Website']],
#  ['Indonesia', 'Wikimedia disambiguation page', []],
#  ['Indonesia', 'board game', []],
#  ['Binamu', 'Kabupaten Jeneponto', []],
#  ['Indonesia', '1981 single by Sandra Reemer', []],
#  ['Indonesia', 'Kompastv', []],
#  ['Indonesia', None, []],
#  ['Indonesia', None, []],
#  ['Indonesia', 'scientific article published on 01 April 1989', []],
#  ['Indonesia', None, []],
#  ['Indonesia', None, []],
#  ['Indonesia', None, []],
#  ['Indonesia', 'scientific article published on 01 April 2020', []],
#  ['Indonesia', None, []],
#  ['Indonesia', None, []],
#  ['Indonesian Rupiah', 'official currency of Indonesia', ['Currency']],
#  ['Indonesia national football team',
#   "men's national association football team representing Indonesia",
#   ['SoccerClub']],
#  ['regency of Indonesia',
#   'Indonesian administrative division, second-level',
#   []],
#  ['provinces of Indonesia', 'first-level subdivision of Indonesia', []],
#  ['Indonesian Democratic Party – Struggle',
#   'political party in Indonesia',
#   []],
#  ['Indonesia Stock Exchange',
#   'Stock exchange located in Jakarta, Indonesia',
#   []],
#  ['2014 Indonesian legislative election', None, ['Election']],
#  ['fourth-level administrative division in Indonesia',
#   'Indonesian fourth administrative division, part of  kecamatan, with a limited level of government administration. It has various national (wilayah) and local (including gampong, kampung, desa, pekon, kelurahan, nagari, etc.) designations',
#   []],
#  ['Kereta Api Indonesia',
#   'train operator company in Indonesia',
#   ['PublicTransitSystem']],
#  ['Acta medica Indonesiana', 'journal', []],
#  ['Indonesia–Malaysia confrontation',
#   'military conflict (1963–1966)',
#   ['MilitaryConflict']],
#  ['pekon',
#   'type of village or wilayah at the fourth level of administrative subdivisions of Indonesia, used in Lampung Province, Sumatra',
#   []],
#  ['Indonesian National Revolution',
#   'armed conflict and diplomatic struggle between Indonesia and the Dutch Empire',
#   ['MilitaryConflict']],
#  ['Military Academy',
#   'army education school in Central Java, Indonesia',
#   ['University']],
#  ['Indonesian Navy',
#   "maritime warfare branch of Indonesia's military",
#   ['MilitaryUnit']],
#  ['Indonesia national under-23 football team',
#   'national association football team',
#   ['SoccerClub']],
#  ['Liga 1',
#   'Indonesian top-flight association football league',
#   ['SoccerLeague']],
#  ['flag of Indonesia', 'national flag of Indonesia', []],
#  ['Indonesian National Armed Forces',
#   'military forces of Indonesia',
#   ['MilitaryUnit']],
#  ['Indonesian cuisine', 'culinary traditions of Indonesia', ['owl#Thing']],
#  ['Template:Id icon', 'Wikimedia template', []],
#  ['AirAsia Flight 8501',
#   '2014 plane crash of an Indonesia AirAsia A320-216 into the Java Sea',
#   []],
#  ['Indonesian Air Force Academy', None, ['University']],
#  ['Indonesia Raya', 'Indonesian national anthem', []],
#  ['Template:Lang-id', 'Wikimedia template', []],
#  ['Indonesian Naval Academy', None, ['University']],
#  ['Indonesian Air Force',
#   "air warfare branch of Indonesia's military",
#   ['MilitaryUnit']],
#  ['nasi goreng', 'Indonesian fried rice', ['Food']],
#  ['geography of Indonesia',
#   "geography that isn't man made and is down to the environment such as volcanoes",
#   ['owl#Thing']],
#  ['Indonesia at the 2016 Summer Olympics',
#   'list of participants from Indonesia',
#   []],
#  ['Indonesia at the Olympics',
#   'Participation of athletes from Indonesia in the Olympic Games',
#   ['owl#Thing']],
#  ['South Africa', 'sovereign state in Southern Africa', ['Country']],
#  ['South Africa', 'Wikimedia disambiguation page', []],
#  ['South Africa', 'article', []],
#  ['South Africa Publications', 'former map publisher in England', []],
#  ['South Africa', 'scientific article (publication date: 27 May 1933)', []],
#  ['South Africa', None, []],
#  ['South Africa', 'artificial island of The World archipelago in Dubai', []],
#  ['Second Boer War',
#   'war between two Boer Republics (South African Republic and Orange Free State) and the United Kingdom',
#   ['MilitaryConflict']],
#  ['South Africa',
#   'episode of British comedy television series The Goodies',
#   ['TelevisionEpisode']],
#  ['South Africa', 'song by Ian Gillan and Bernie Marsden', ['Song']],
#  ['South Africa', 'scientific article published in Nature', []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['SOUTH AFRICA', 'scientific article published in December 1927', []],
#  ['SOUTH AFRICA', 'scientific article published in September 1927', []],
#  ['South Africa', 'scientific article published on 01 June 1988', []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', 'journal article; published in Nature on 1986-4', []],
#  ['South Africa', None, []],
#  ['South Africa', 'journal article; published in Nature on 2006-4', []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South africa', 'scientific article published on 01 June 1988', []],
#  ['South Africa', None, []],
#  ['South Africa', 'scientific article published in February 1909', []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', 'scientific article published in September 1906', []],
#  ['South Africa', None, []],
#  ['SOUTH AFRICA', None, []],
#  ['South Africa', None, []],
#  ['South Africa', 'journal article; published in Nature on 1977-1', []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', 'scientific article published on 01 February 1988', []],
#  ['South Africa', 'scientific article published in April 1907', []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['South Africa', None, []],
#  ['University of Cape Town', 'university in Cape Town, South Africa', []],
#  ['South Africa national football team',
#   "South African men's national association football team",
#   ['SoccerClub']],
#  ['Union of South Africa',
#   'state in southern Africa from 1910 to 1961, predecessor to the Republic of South Africa',
#   ['Country']],
#  ['Brazil', 'sovereign state in South America', ['Country']],
#  ['Brazil', '1985 dystopian film by Terry Gilliam', []],
#  ['Brazil', 'city in Indiana, United States', []],
#  ['Brazil', 'Wikimedia disambiguation page', []],
#  ['Brazil', 'family name', []],
#  ['Brazil', '1944 film by Joseph Santley', ['Film']],
#  ['Brazil',
#   'translated song; English version of "Aquarela do Brasil", lyrics adapted by S. K. Russell',
#   []],
#  ['Brazil', '1975 debut studio album by The Ritchie Family', ['Album']],
#  ['Conselho Nacional de Arquivos', 'library', []],
#  ['Brazil',
#   'vocal track by Frank Sinatra; 1957 studio recording; cover version',
#   []],
#  ['Brazil', 'episode of Falling Skies (S3 E10)', []],
#  ['Brazil', 'band from Indiana', ['Band']],
#  ['Brazil', '1991 song by Bebi Dol', ['EurovisionSongContestEntry']],
#  ['Brazil', 'episode of Law & Order (S20 E18)', []],
#  ['Brazil national football team',
#   "men's national association football team representing Brazil",
#   ['SoccerClub']],
#  ['Brazil',
#   '2000 studio album by Rosemary Clooney with John Pizzarelli',
#   ['Album']],
#  ['Brazil',
#   'vocal track by The Ritchie Family; 1975 studio recording; cover version',
#   []],
#  ['brazilwood dye',
#   'red dye extracted from the wood of trees of the genus Caesalpinia',
#   []],
#  ['Brazil', '1994 novel by John Updike', ['Book']],
#  ["Brazil '96", '1998 live album by Men at Work', ['Album']],
#  ['Brazilian Portuguese',
#   'set of dialects of the Portuguese language used mostly in Brazil',
#   ['Language']],
#  ['Brazil', 'painting by Lucien Hervé', []],
#  ['Pernambuco', None, []],
#  ['Brazil', '2012 book by Michael Palin', []],
#  ['Mato Grosso do Sul', None, []],
#  ['Brazil', '1994 edition', []],
#  ['Brazil', 'scientific article published on 01 November 1987', []],
#  ['Brazil', 'painting by L.L. FitzGerald', []],
#  ['Brazil', 'township in Jackson County, Kentucky', []],
#  ['Escola Nacional de Formação e Aperfeiçoamento de Magistrados', None, []],
#  ['Vila do Encontro', 'human settlement in Brazil', []],
#  ['Brazil', 'French monthly film magazine', []],
#  ['Brazil', None, []],
#  ['Brazil', 'unincoporated community in Tallahatchie County, Mississippi', []],
#  ['Conselho Federal de Biblioteconomia', None, []],
#  ['Brazil', 'song', []],
#  ['Conselho Nacional do Meio Ambiente', None, []],
#  ['Banco Nacional do Desenvolvimento Econômico',
#   'archive in Rio de Janeiro, Rio de Janeiro',
#   []],
#  ['Brazil', 'journal article; published in Nature on 1976-9', []],
#  ['Brazil', 'scientific article published on 01 September 1991', []],
#  ['Brazil', 'scientific article published on 01 January 1988', []],
#  ['Brazil', 'scientific article published in Nature', []],
#  ['BRAZIL', 'journal article; published in Nature on 1976-2', []],
#  ['Brazil', None, []],
#  ['Brazil', 'scientific article published on 01 December 2009', []],
#  ['Brazil', 'journal article; published in Nature on 1976-7', []],
#  ['Brazil', 'journal article; published in Nature on 2005-10-01', []],
#  ['Brazil', 'cinema in Schwäbisch Gmünd, Baden-Württemberg, Germany', []],
#  ['Brazil', None, []],
#  ['mandolin', 'musical instrument in the lute family', []],
#  ['Jamaica', 'island sovereign state in the Caribbean Sea', ['Country']],
#  ['Jamaica', 'neighborhood of Queens, New York City', []],
#  ['Jamaica', 'city in Iowa, United States', []],
#  ['Jamaica', 'Wikimedia disambiguation page', []],
#  ['Jamaica', 'town in Vermont, United States', []],
#  ['Colony of Jamaica',
#   'British colony on the island of Jamaica, 1655–1962',
#   ['Country']],
#  ['HMS Jamaica', 'cruiser', ['Ship']],
#  ['Jamaica',
#   'Long Island Rail Road train station in Queens, New York',
#   ['Station']],
#  ['Jamaica', 'AirTrain JFK station in Queens, New York', []],
#  ['Jamaica', 'French band', []],
#  ['Jamaica', 'island in the Caribbean', []],
#  ['Jamaica', 'unincorporated community in Virginia', []],
#  ['Jamaica', 'human settlement in Mexico', []],
#  ['Jamaica', 'family name', []],
#  ['Jamaica', 'musical', ['Musical']],
#  ["Dahlia 'Jamaica'", 'Dahlia cultivar', []],
#  ['Jamaica', '2007 novel by Malcolm Knox', ['Book']],
#  ['Jamaica', None, []],
#  ['Jamaica', 'single by Bachman–Turner Overdrive', ['Song']],
#  ['Jamaica', 'song of Ben E. King', []],
#  ['Jamaica', 'scientific article published on 01 November 1987', []],
#  ['Jamaica', 'scientific article published on 01 August 1912', []],
#  ['Jamaica', 'passenger/general cargo ship built in 1908', []],
#  ['Jamaica', 'scientific article published in Nature', []],
#  ['Jamaica', 'scientific article published on 01 March 1906', []],
#  ['Jamaica', 'scientific article published on 01 July 1910', []],
#  ['Jamaica', 'scientific article published on 01 April 1910', []],
#  ['Jamaica', 'scientific article published on 01 January 1987', []],
#  ['Jamaica', 'scientific article published on 01 December 1911', []],
#  ['Jamaica', 'painting by Fred Wilson', []],
#  ['Jamaica', 'street in Zoetermeer, the Netherlands', []],
#  ['Jamaica', 'scientific article published on 01 November 1910', []],
#  ['Jamaica', 'scientific article published on 01 May 1913', []],
#  ['Jamaica', 'scientific article published on 01 September 1922', []],
#  ['Jamaica national football team',
#   "men's national association football team representing Jamaica",
#   ['SoccerClub']],
#  ['Jamaican Patois', 'creole language spoken in Jamaica', ['Language']],
#  ['flag of Jamaica', 'flag', []],
#  ['Jamaica Kincaid',
#   'Antiguan-American novelist, essayist, gardener, and gardening writer',
#   ['Writer']],
#  ['Jamaican dollar', 'currency', ['Currency']],
#  ['Jamaica Labour Party', 'Jamaican political party', ['PoliticalParty']],
#  ['The Jamaican nurse', 'journal', []],
#  ['Annona reticulata', 'species of plant', []],
#  ['Jamaican fruit bat', 'species of mammal', []],
#  ['Jamaica, Land We Love', 'national anthem of Jamaica', []],
#  ['Jamaica national cricket team', 'sports team', ['CricketTeam']],
#  ['Jamaica Plain', 'neighborhood in Boston, Massachusetts, United States', []],
#  ['Haematoxylum campechianum', 'species of plant', []],
#  ['Jamaica at the Olympics',
#   'Participation of athletes from Jamaica in the Olympic Games',
#   ['owl#Thing']],
#  ['Muntingia calabura', 'species of plant', []],
#  ["Jamaica women's national football team",
#   "women's national association football team representing Jamaica",
#   ['SoccerClub']],
#  ['Canada', 'sovereign state in North America', ['Country']],
#  ['Province of Canada',
#   '1841–1867 UK possession in North America',
#   ['Country']],
#  ['Canada',
#   'former French colony in New France between the years of 1534 and 1763',
#   ['Country']],
#  ...]

# %%
num_entities = []
num_candidates = []
for table in tables:
    _, _, _, _, _, entities, candidate_entities, _, _ = table
    num_entities.append(len(entities))
    num_candidates.append(len(candidate_entities))

# %%
len(num_entities), len(num_candidates)
# Out:
# (809, 809)

# %%
np.mean(num_entities), np.std(num_entities)
# Out:
# (76.81087762669964, 18.49117199173145)

# %%
np.mean(num_candidates), np.std(num_candidates)
# Out:
# (552.9060568603214, 500.2470871065791)

# %%
np.max(num_entities), np.max(num_candidates)
# Out:
# (147, 2146)

# %%
idx_max_num_candidates = np.argmax(num_candidates)
num_entities[idx_max_num_candidates]
# Out:
# 132

# %%
tables_df = pd.DataFrame(
    tables,
    columns=["table_id", "pgTitle", "secTitle", "caption", "headers", "entities", "candidate_entities", "labels", ""],
)

# %%
tables_df.groupby("pgTitle").size().gt(1).sum()
# Out:
# 124
